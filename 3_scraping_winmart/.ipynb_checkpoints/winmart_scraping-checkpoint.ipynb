# %% [markdown]
# В этом блокноте мы занимаемся скачиванием продуктов с сайта Winmart

# %% [markdown]
# Для начала нам нужно импортировать нужные библиотеки и задать константы. Это параметры запросов к сайту.

# %%
import requests
import json
import time
import random
import pandas as pd
from datetime import date

# define constants for requests

CATEGORIES_URL = "https://api-crownx.winmart.vn/mt/api/web/v1/category"
CHECK_DATE = date.today() # current date for reference

HEADERS = {
    'origin': 'https://winmart.vn',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36'
}

# %% [markdown]
# Так как скачивать продукты мы будем по категориям, нужно получить список категорий товаров с сайта. За это будет отвечать следующая функция, которая запросит у сайта список категорий и подкатегорий, выберет только id и названия категорий и сохранит данные в словарь.

# %%
def fetch_categories():
    
    response = requests.get(CATEGORIES_URL, headers=HEADERS) # get the data
    raw_categories = json.loads(response.text) # convert into a dictionary

    cleaned_categories = []
    
    # go through the raw data and select only the necessary fields
    for category in raw_categories["data"]:    # select the broad category, save its id and name
        cleaned_categories.append({
            "code": category["parent"]["code"],
            "name": category["parent"]["name"],
            "parent_id": None,
            "parent_name": None,
            "has_child": True if category["lstChild"] else False,
            "slug": category["parent"]["seoName"], # to create an items request
            "level": category["parent"]["level"] # to avoid double scanning subcategories
        })
        if category["lstChild"]:    # if category has children, go through them too
            for child in category["lstChild"]:
                cleaned_categories.append({
                    "code": child["parent"]["code"],
                    "name": child["parent"]["name"],
                    "parent_id": category["parent"]["code"],
                    "parent_name": category["parent"]["name"],
                    "has_child": False,
                    "slug": child["parent"]["seoName"], # to create an items request
                    "level": child["parent"]["level"] # to avoid double scanning subcategories
                })

    return cleaned_categories

# %% [markdown]
# Загружаем категории в отдельном блоке, чтобы не повторять эту операцию.

# %%
categories = fetch_categories()
categories_df = pd.DataFrame(categories)
categories_df.to_csv(f'categories-{CHECK_DATE}-winmart.csv', index=False)
print(categories)
# Out:
# [{'code': 'MENU114', 'name': 'Giá Siêu Rẻ', 'parent_id': None, 'parent_name': None, 'has_child': False, 'slug': 'gia-sieu-re--c114', 'level': 1}, {'code': 'MENU51', 'name': 'Ưu Đãi Hội Viên', 'parent_id': None, 'parent_name': None, 'has_child': False, 'slug': 'uu-dai-hoi-vien--c51', 'level': 1}, {'code': 'MENU08', 'name': 'Sữa các loại', 'parent_id': None, 'parent_name': None, 'has_child': True, 'slug': 'sua-cac-loai--c08', 'level': 1}, {'code': 'MENU0133', 'name': 'Sữa Tươi', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'sua-tuoi--c0133', 'level': 2}, {'code': 'MENU0134', 'name': 'Sữa Hạt - Sữa Đậu', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'sua-hat-sua-dau--c0134', 'level': 2}, {'code': 'MENU0135', 'name': 'Sữa Bột', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'sua-bot--c0135', 'level': 2}, {'code': 'MENU0138', 'name': 'Bơ Sữa - Phô Mai', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'bo-sua-pho-mai--c0138', 'level': 2}, {'code': 'MENU01161', 'name': 'Sữa đặc', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'sua-dac--c01161', 'level': 2}, {'code': 'MENU01169', 'name': 'Sữa Chua - Váng Sữa', 'parent_id': 'MENU08', 'parent_name': 'Sữa các loại', 'has_child': False, 'slug': 'sua-chua-vang-sua--c01169', 'level': 2}, {'code': 'MENU02', 'name': 'Rau - Củ - Trái Cây', 'parent_id': None, 'parent_name': None, 'has_child': True, 'slug': 'rau-cu-trai-cay--c02', 'level': 1}, {'code': 'MENU01167', 'name': 'Rau Lá', 'parent_id': 'MENU02', 'parent_name': 'Rau - Củ - Trái Cây', 'has_child': False, 'slug': 'rau-la--c01167', 'level': 2}, {'code': 'MENU01168', 'name': 'Củ, Quả', 'parent_id': 'MENU02', 'parent_name': 'Rau - Củ - Trái Cây', 'has_child': False, 'slug': 'cu-qua--c01168', 'level': 2}, {'code': 'MENU01173', 'name': 'Trái cây tươi', 'parent_id': 'MENU02', 'parent_name': 'Rau - Củ - Trái Cây', 'has_child': False, 'slug': 'trai-cay-tuoi--c01173', 'level': 2}, {'code': 'MENU10', 'name': 'Hóa Phẩm - Tẩy rửa', 'parent_id': None, 'parent_name': None, 'has_child': True, 'slug': 'hoa-pham-tay-rua--c10', 'level': 1}, {'code': 'MENU01140', 'name': 'Nước Giặt', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'nuoc-giat--c01140', 'level': 2}, {'code': 'MENU01144', 'name': 'Nước Xả', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'nuoc-xa--c01144', 'level': 2}, {'code': 'MENU01142', 'name': 'Nước Rửa Chén', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'nuoc-rua-chen--c01142', 'level': 2}, {'code': 'MENU01139', 'name': 'Bình Xịt Côn Trùng', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'binh-xit-con-trung--c01139', 'level': 2}, {'code': 'MENU01141', 'name': 'Nước Lau Sàn - Lau Kính', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'nuoc-lau-san-lau-kinh--c01141', 'level': 2}, {'code': 'MENU01143', 'name': 'Nước Tẩy Rửa', 'parent_id': 'MENU10', 'parent_name': 'Hóa Phẩm - Tẩy rửa', 'has_child': False, 'slug': 'nuoc-tay-rua--c01143', 'level': 2}, {'code': 'MENU11', 'name': 'Chăm Sóc Cá Nhân', 'parent_id': None, 'parent_name': None, 'has_child': True, 'slug': 'cham-soc-ca-nhan--c11', 'level': 1}, {'code': 'MENU0147', 'name': 'Chăm Sóc Răng Miệng', 'parent_id': 'MENU11', 'parent_name': 'Chăm Sóc Cá Nhân', 'has_child': False, 'slug': 'cham-soc-rang-mieng--c0147', 'level': 2}, {'code': 'MENU0146', 'name': 'Chăm Sóc Da', 'parent_id': 'MENU11', 'parent_name': 'Chăm Sóc Cá Nhân', 'has_child': False, 'slug': 'cham-soc-da--c0146', 'level': 2}, {'code': 'MENU0145', 'name': 'Chăm Sóc Tóc', 'parent_id': 'MENU11', 'parent_name': 'Chăm Sóc Cá Nhân', 'has_child': False, 'slug': 'cham-soc-toc--c0145', 'level': 2}, {'code': 'MENU0148', 'name': 'Chăm Sóc Phụ Nữ', 'parent_id': 'MENU1 ...

# %%
categories_end = [cat for cat in categories if not cat['has_child']] # choose only childless categories
categories_end = categories_end[71:]
print(categories_end)
total_categories_count = len(categories_end)
total_categories_count
# Out:
# [{'code': 'MENU01133', 'name': 'Đồ dùng nhà bếp', 'parent_id': 'MENU25', 'parent_name': 'Đồ Dùng Gia Đình', 'has_child': False, 'slug': 'do-dung-nha-bep--c01133', 'level': 2}, {'code': 'MENU01136', 'name': 'Thiết bị dùng điện trong nhà', 'parent_id': 'MENU25', 'parent_name': 'Đồ Dùng Gia Đình', 'has_child': False, 'slug': 'thiet-bi-dung-dien-trong-nha--c01136', 'level': 2}, {'code': 'MENU01170', 'name': 'Vệ Sinh Nhà Cửa', 'parent_id': 'MENU25', 'parent_name': 'Đồ Dùng Gia Đình', 'has_child': False, 'slug': 've-sinh-nha-cua--c01170', 'level': 2}, {'code': 'MENU26', 'name': 'Điện Gia Dụng', 'parent_id': None, 'parent_name': None, 'has_child': False, 'slug': 'dien-gia-dung--c26', 'level': 1}, {'code': 'MENU27', 'name': 'Văn Phòng Phẩm - Đồ Chơi', 'parent_id': None, 'parent_name': None, 'has_child': False, 'slug': 'van-phong-pham-do-choi--c27', 'level': 1}]
# 5

# %%
# fetch the raw product data (the site uses an increasing offset to fetch all the products, we mimic this behavior)

def fetch_products(category):
    
    # total_products = 1 # just a random non-zero value to start with
    # offset = 0
    products = []

    ITEMS_URL = "https://api-crownx.winmart.vn/it/api/web/v3/item/category"
    PARAMS = {
            'orderByDesc': 'true',
            'pageNumber': '1',
            'pageSize': '8',
            'slug': category["slug"],
            'storeCode': '1561',
            'storeGroupCode': '1999',
        }
    
    response = requests.get(ITEMS_URL, headers=HEADERS, params=PARAMS) # get the data
    response_data = json.loads(response.text) # convert into a dictionary
    total_pages = response_data["paging"]["totalPages"]
    
    for page in range(1, total_pages + 1):
        time.sleep(random.uniform(1, 5)) # random time delay to avoid being blocked
        
        PARAMS = {
            'orderByDesc': 'true',
            'pageNumber': str(page),
            'pageSize': '8',
            'slug': category['slug'],
            'storeCode': '1561',
            'storeGroupCode': '1999',
        }
    
        response = requests.get(ITEMS_URL, headers=HEADERS, params=PARAMS) # get the data
        response_data = json.loads(response.text) # convert into a dictionary
        products += response_data["data"]["items"] # extract only products and add them to the list
        
        print(f'{len(products)}..', end='') # progress indication

    return products

# %%
raw_products = fetch_products(categories_end[0]) # fetch products
# Out:
# 8..16..24..

# %%
raw_products
# Out:
# [{'id': 'd7cdc934-1856-4089-b26b-713ed77030af',
#   'itemNo': '10333557',
#   'brand': '10098',
#   'seoName': 'lix-nuoc-giat-huong-nang-ha-33kg31kg--s10333557',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2025/02/lix-1-1-20250207091638.png',
#   'description': 'LIX Nước giặt hương nắng hạ 3,3kg/3,1kg',
#   'name': 'LIX Nước giặt hương nắng hạ 3,3kg/3,1kg',
#   'itemType': 'ZTRD',
#   'uomId': '7b76539a-c816-45ee-9f3d-f4a58e778101',
#   'uom': 'CAN',
#   'uomName': 'Can',
#   'quantityPerUnit': 1.0,
#   'sku': '10333557CAN',
#   'barcode': '8934669241455',
#   'price': 199000.0,
#   'salePrice': 115000.0,
#   'quantity': 239.0,
#   'promotionCode': '2300284810',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '2',
#   'mch1Name': 'Phi thực phẩm',
#   'mch2': '202',
#   'mch2Name': 'Hoá mỹ phẩm',
#   'mch3': '20202',
#   'mch3Name': 'Hóa phẩm',
#   'mch4': '2020201',
#   'mch4Name': 'Chất giặt tẩy',
#   'mch5': '202020104',
#   'mch5Name': 'Nước giặt',
#   'brandName': 'LIX',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2025/02/lix-1-1-20250207091638.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2025/02/thiet-ke-chua-co-ten-4--20250207073041.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/11/1-2--20231114042514.jpg'}],
#   'uoms': [{'uom': 'CAN',
#     'uomId': '7b76539a-c816-45ee-9f3d-f4a58e778101',
#     'uomName': 'Can',
#     'sku': '10333557CAN',
#     'description': 'LIX Nước giặt hương nắng hạ 3,3kg/3,1kg',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 199000.0,
#     'salePrice': 115000.0,
#     'quantity': 239.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2025/02/lix-1-1-20250207091638.png',
#     'promotionCode': '2300284810',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8934669241455',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '07497f33-9831-430e-9668-2c6d3144ad97',
#   'itemNo': '10198354',
#   'brand': '16343',
#   'seoName': 'green-ace-dau-dau-nanh-2l--s10198354',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/09/untitled-20240927020231.png',
#   'description': 'GREEN ACE Dầu đậu nành 2L',
#   'name': 'GREEN ACE Dầu đậu nành 2L',
#   'itemType': 'ZTRD',
#   'uomId': '2b1cc61e-3412-4e2e-8f61-f272b598d87d',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10198354CHA',
#   'barcode': '8938526259225',
#   'price': 129000.0,
#   'salePrice': 79900.0,
#   'quantity': 208.0,
#   'promotionCode': '2300357739',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020602',
#   'mch4Name': 'Dầu ăn',
#   'mch5': '102060207',
#   'mch5Name': 'Dầu nành',
#   'brandName': 'GREEN ACE',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/09/untitled-20240927020231.png'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '2b1cc61e-3412-4e2e-8f61-f272b598d87d',
#     'uomName': 'Chai',
#     'sku': '10198354CHA',
#     'description': 'GREEN ACE Dầu đậu nành 2L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 129000.0,
#     'salePrice': 79900.0,
#     'quantity': 208.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/09/untitled-20240927020231.png',
#     'promotionCode': '2300357739',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8938526259225',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '1eb7a527-b6e3-471e-b0fc-5430f6468ffd',
#   'itemNo': '10010686',
#   'brand': '10027',
#   'seoName': 'nutri-boost-nuoc-ngot-cam-sua-1l--s10010686',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010686-20241109091107.jpg',
#   'description': 'Nước uống sữa trái cây bổ dưỡng hương cam Nutri Boost chai 1L',
#   'name': 'Nước uống sữa trái cây bổ dưỡng hương cam Nutri Boost chai 1L',
#   'itemType': 'ZTRD',
#   'uomId': '49584567-77ce-4595-a02f-fb2f8698256f',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10010686CHA',
#   'barcode': '893504951073',
#   'price': 29000.0,
#   'salePrice': 18800.0,
#   'quantity': 110.0,
#   'promotionCode': '2300381004',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10203',
#   'mch3Name': 'Đồ uống, thuốc lá',
#   'mch4': '1020304',
#   'mch4Name': 'Nước uống không cồn và hoa quả',
#   'mch5': '102030410',
#   'mch5Name': 'Nước uống dinh dưỡng',
#   'brandName': 'NUTRI BOOST',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010686-20241109091107.jpg'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '49584567-77ce-4595-a02f-fb2f8698256f',
#     'uomName': 'Chai',
#     'sku': '10010686CHA',
#     'description': 'Nước uống sữa trái cây bổ dưỡng hương cam Nutri Boost chai 1L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 29000.0,
#     'salePrice': 18800.0,
#     'quantity': 110.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010686-20241109091107.jpg',
#     'promotionCode': '2300381004',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '893504951073',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'f4c75e6a-7921-42c7-8324-6e1db6e95e33',
#   'itemNo': '10010687',
#   'brand': '10027',
#   'seoName': 'nutri-boost-nuoc-ngot-dau-sua-1l--s10010687',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010687-20241109091127.jpg',
#   'description': 'Nước uống sữa trái cây hương dâu Nutri Boost chai 1L',
#   'name': 'Nước uống sữa trái cây hương dâu Nutri Boost chai 1L',
#   'itemType': 'ZTRD',
#   'uomId': '6cf99a57-87a1-4bb2-ab3c-724bec957f92',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10010687CHA',
#   'barcode': '8935049511854',
#   'price': 29000.0,
#   'salePrice': 18800.0,
#   'quantity': 101.0,
#   'promotionCode': '2300381003',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10203',
#   'mch3Name': 'Đồ uống, thuốc lá',
#   'mch4': '1020304',
#   'mch4Name': 'Nước uống không cồn và hoa quả',
#   'mch5': '102030410',
#   'mch5Name': 'Nước uống dinh dưỡng',
#   'brandName': 'NUTRI BOOST',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010687-20241109091127.jpg'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '6cf99a57-87a1-4bb2-ab3c-724bec957f92',
#     'uomName': 'Chai',
#     'sku': '10010687CHA',
#     'description': 'Nước uống sữa trái cây hương dâu Nutri Boost chai 1L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 29000.0,
#     'salePrice': 18800.0,
#     'quantity': 101.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10010687-20241109091127.jpg',
#     'promotionCode': '2300381003',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8935049511854',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'd3846491-d562-4619-a137-94aa0a568bb2',
#   'itemNo': '10010076',
#   'brand': '15440',
#   'seoName': 'meizan-dau-dau-nanh-chai-2l--s10010076',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/packg_meizan-2l-sbo-new-20230526031537.png',
#   'description': 'Dầu đậu nành Meizan chai 2L',
#   'name': 'Dầu đậu nành Meizan chai 2L',
#   'itemType': 'ZTRD',
#   'uomId': '28f2a283-6e21-4c32-83f6-c91d098f6da9',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10010076CHA',
#   'barcode': '8934988021547',
#   'price': 128900.0,
#   'salePrice': 91900.0,
#   'quantity': 28.0,
#   'promotionCode': '2300388362',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020602',
#   'mch4Name': 'Dầu ăn',
#   'mch5': '102060207',
#   'mch5Name': 'Dầu nành',
#   'brandName': 'MEIZAN',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/packg_meizan-2l-sbo-new-20230526031537.png'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '28f2a283-6e21-4c32-83f6-c91d098f6da9',
#     'uomName': 'Chai',
#     'sku': '10010076CHA',
#     'description': 'Dầu đậu nành Meizan chai 2L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 128900.0,
#     'salePrice': 91900.0,
#     'quantity': 28.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/packg_meizan-2l-sbo-new-20230526031537.png',
#     'promotionCode': '2300388362',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8934988021547',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '27e9b154-5374-4089-9749-fbe61d716670',
#   'itemNo': '10198356',
#   'brand': '12016',
#   'seoName': '3-mien-mi-ga-soi-pho-65g--s10198356',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/frame-2-8--20241104093203.jpg',
#   'description': '3 MIỀN Mì gà sợi phở 65g',
#   'name': '3 MIỀN Mì gà sợi phở 65g',
#   'itemType': 'ZTRD',
#   'uomId': 'a9213b77-183c-4bc8-ae6a-5eaa96a8fd6b',
#   'uom': 'T',
#   'uomName': 'Thùng',
#   'quantityPerUnit': 30.0,
#   'sku': '10198356T',
#   'barcode': '8936048473938',
#   'price': 101000.0,
#   'salePrice': 72900.0,
#   'quantity': 16.0,
#   'promotionCode': '2300285901',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020609',
#   'mch4Name': 'Thực phẩm ăn liền',
#   'mch5': '102060905',
#   'mch5Name': 'Mì ăn liền',
#   'brandName': '3 MIỀN',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/frame-2-8--20241104093203.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2024/10/frame-2-6--20241029094109.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2024/09/thung-30-goi-mi-3-mien-ga-soi-pho-goi-65g-202406131345058236-20240927020500.jpg'}],
#   'uoms': [{'uom': 'T',
#     'uomId': 'a9213b77-183c-4bc8-ae6a-5eaa96a8fd6b',
#     'uomName': 'Thùng',
#     'sku': '10198356T',
#     'description': '3 MIỀN Mì gà sợi phở 65g',
#     'priority': 0,
#     'quantityPerUnit': 30.0,
#     'price': 101000.0,
#     'salePrice': 72900.0,
#     'quantity': 16.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/frame-2-8--20241104093203.jpg',
#     'promotionCode': '2300285901',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8936048473938',
#     'variants': []},
#    {'uom': 'G1',
#     'uomId': 'f5cd469f-2ee9-4f8d-a388-4108be7677c2',
#     'uomName': 'Gói',
#     'sku': '10198356G1',
#     'description': '3 MIỀN Mì gà sợi phở 65g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 3500.0,
#     'salePrice': 2800.0,
#     'quantity': 499.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/10/frame-2-6--20241029094109.jpg',
#     'promotionCode': '2300285900',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8936048473921',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '1a97118f-dac7-4013-ab97-c845fa325152',
#   'itemNo': '10141993',
#   'brand': '15889',
#   'seoName': 'ngoc-nuong-gao-st-25-dac-san-3kg-vns--s10141993',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10141993-20241109090819.jpg',
#   'description': 'Gạo Ngọc Nương ST 25 đặc sản 3Kg ',
#   'name': 'Gạo Ngọc Nương ST 25 đặc sản 3Kg ',
#   'itemType': 'ZTRD',
#   'uomId': '5ffbec15-e767-429d-a6fd-72520cb58ac7',
#   'uom': 'G1',
#   'uomName': 'Gói',
#   'quantityPerUnit': 1.0,
#   'sku': '10141993G1',
#   'barcode': '8934954015358',
#   'price': 123000.0,
#   'salePrice': 97900.0,
#   'quantity': 545.0,
#   'promotionCode': '2300380557',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020604',
#   'mch4Name': 'Gạo & Nông sản khô',
#   'mch5': '102060401',
#   'mch5Name': 'Gạo tẻ',
#   'brandName': 'NGỌC NƯƠNG',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10141993-20241109090819.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/04/ngoc-nuong-gao-st-25-dac-san-3kg-vns-1--20230426095943.png'}],
#   'uoms': [{'uom': 'G1',
#     'uomId': '5ffbec15-e767-429d-a6fd-72520cb58ac7',
#     'uomName': 'Gói',
#     'sku': '10141993G1',
#     'description': 'Gạo Ngọc Nương ST 25 đặc sản 3Kg ',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 123000.0,
#     'salePrice': 97900.0,
#     'quantity': 545.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10141993-20241109090819.jpg',
#     'promotionCode': '2300380557',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8934954015358',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '233d6420-edcb-4c88-9c4e-cdb28c66334f',
#   'itemNo': '10005342',
#   'brand': '10159',
#   'seoName': 'kun-sua-vi-cacao-lua-mach-hop-110ml--s10005342',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10005342-20241109110745.jpg',
#   'description': 'Sữa KUN vị cacao lúa mạch hộp 110ml ',
#   'name': 'Sữa KUN vị cacao lúa mạch hộp 110ml ',
#   'itemType': 'ZTRD',
#   'uomId': '630b2f5b-135c-4e4f-a189-88701c1a3b24',
#   'uom': 'G4',
#   'uomName': 'Gói 4',
#   'quantityPerUnit': 4.0,
#   'sku': '10005342G4',
#   'barcode': '8936025771118',
#   'price': 20000.0,
#   'salePrice': 16500.0,
#   'quantity': 5.0,
#   'promotionCode': '2300286246',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10202',
#   'mch3Name': 'Bơ, sữa, trứng',
#   'mch4': '1020206',
#   'mch4Name': 'Sữa tươi',
#   'mch5': '102020602',
#   'mch5Name': 'Sữa tươi tiệt trùng',
#   'brandName': 'KUN',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10005342-20241109110745.jpg'}],
#   'uoms': [{'uom': 'G4',
#     'uomId': '630b2f5b-135c-4e4f-a189-88701c1a3b24',
#     'uomName': 'Gói 4',
#     'sku': '10005342G4',
#     'description': 'Sữa KUN vị cacao lúa mạch hộp 110ml ',
#     'priority': 0,
#     'quantityPerUnit': 4.0,
#     'price': 20000.0,
#     'salePrice': 16500.0,
#     'quantity': 5.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10005342-20241109110745.jpg',
#     'promotionCode': '2300286246',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8936025771118',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'a74bc68e-dd2f-4eef-a10f-3fb916c65e39',
#   'itemNo': '10007930',
#   'brand': '10549',
#   'seoName': 'kokomi-mi-tom-chua-cay-65g--s10007930',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/mi-tom-chua-cay-kokomi-65g-20230511021234.jpg',
#   'description': 'Thùng 30 gói mì ăn liền\xa0vị tôm chua cay Kokomi\xa065g',
#   'name': 'Thùng 30 gói mì ăn liền\xa0vị tôm chua cay Kokomi\xa065g',
#   'itemType': 'ZTRD',
#   'uomId': '57af3175-c426-45d5-8e14-0f77c48febb8',
#   'uom': 'T',
#   'uomName': 'Thùng',
#   'quantityPerUnit': 30.0,
#   'sku': '10007930T',
#   'barcode': '8936017367121',
#   'price': 91000.0,
#   'salePrice': 74900.0,
#   'quantity': 13.0,
#   'promotionCode': '2300285899',
#   'promotionType': 'ZB10',
#   'scaleType': 'UPTO',
#   'scaleQuantity': 3.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020609',
#   'mch4Name': 'Thực phẩm ăn liền',
#   'mch5': '102060905',
#   'mch5Name': 'Mì ăn liền',
#   'brandName': 'KOKOMI',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/mi-tom-chua-cay-kokomi-65g-20230511021234.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2022/162428262556110007930-t-gang-tay-cao-su-komax-51001-size-l-og.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/07/kokomi-mi-tom-chua-cay-thung-30-goix65g-20230727063147.jpg'}],
#   'uoms': [{'uom': 'T',
#     'uomId': '57af3175-c426-45d5-8e14-0f77c48febb8',
#     'uomName': 'Thùng',
#     'sku': '10007930T',
#     'description': 'Thùng 30 gói mì ăn liền\xa0vị tôm chua cay Kokomi\xa065g',
#     'priority': 0,
#     'quantityPerUnit': 30.0,
#     'price': 91000.0,
#     'salePrice': 74900.0,
#     'quantity': 13.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/mi-tom-chua-cay-kokomi-65g-20230511021234.jpg',
#     'promotionCode': '2300285899',
#     'promotionType': 'ZB10',
#     'scaleType': 'UPTO',
#     'scaleQuantity': 3.0,
#     'barcode': '8936017367121',
#     'variants': []},
#    {'uom': 'G1',
#     'uomId': '2867a667-1eda-49b2-801c-5a422ea76a3f',
#     'uomName': 'Gói',
#     'sku': '10007930G1',
#     'description': 'Mì tôm chua cay Kokomi gói 65g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 3100.0,
#     'salePrice': 2600.0,
#     'quantity': 394.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/07/kokomi-mi-tom-chua-cay-thung-30-goix65g-20230727063147.jpg',
#     'promotionCode': '2300285898',
#     'promotionType': 'ZB10',
#     'scaleType': 'UPTO',
#     'scaleQuantity': 90.0,
#     'barcode': '8936136160887',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '0324a0c9-ca80-4cf9-8590-1bca8d755f3f',
#   'itemNo': '10010075',
#   'brand': '15440',
#   'seoName': 'meizan-dau-dau-nanh-chai-1l--s10010075',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/dau-dau-nanh-meizan-chai-1-lit-202303152139340926-20230526031248.jpg',
#   'description': 'Dầu đậu nành Meizan chai 1L',
#   'name': 'Dầu đậu nành Meizan chai 1L',
#   'itemType': 'ZTRD',
#   'uomId': '5ce145b6-5caf-4565-a999-d3fcfb09781f',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10010075CHA',
#   'barcode': '8934988021530',
#   'price': 55800.0,
#   'salePrice': 45900.0,
#   'quantity': 124.0,
#   'promotionCode': '2300388361',
#   'promotionType': 'ZB10',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020602',
#   'mch4Name': 'Dầu ăn',
#   'mch5': '102060207',
#   'mch5Name': 'Dầu nành',
#   'brandName': 'MEIZAN',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/dau-dau-nanh-meizan-chai-1-lit-202303152139340926-20230526031248.jpg'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '5ce145b6-5caf-4565-a999-d3fcfb09781f',
#     'uomName': 'Chai',
#     'sku': '10010075CHA',
#     'description': 'Dầu đậu nành Meizan chai 1L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 55800.0,
#     'salePrice': 45900.0,
#     'quantity': 124.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/dau-dau-nanh-meizan-chai-1-lit-202303152139340926-20230526031248.jpg',
#     'promotionCode': '2300388361',
#     'promotionType': 'ZB10',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '8934988021530',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'dc0b4646-ab5b-4137-85c7-a1f26eea81bf',
#   'itemNo': '10008683',
#   'brand': '10088',
#   'seoName': 'nam-ngu-nuoc-cham-de-nhi-900ml--s10008683',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/nuoc-mam-nam-ngu-de-nhi-900ml-20230228071002.jpg',
#   'description': 'Nước mắm Nam Ngư Đệ nhị 900ml',
#   'name': 'Nước mắm Nam Ngư Đệ nhị 900ml',
#   'itemType': 'ZTRD',
#   'uomId': 'd350cb40-114d-426b-80d3-308eb47df55c',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10008683CHA',
#   'barcode': '8936017361914',
#   'price': 26500.0,
#   'salePrice': 22000.0,
#   'quantity': 114.0,
#   'promotionCode': '2300285902',
#   'promotionType': 'ZB10',
#   'scaleType': 'UPTO',
#   'scaleQuantity': 5.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020605',
#   'mch4Name': 'Gia vị',
#   'mch5': '102060511',
#   'mch5Name': 'Nước mắm',
#   'brandName': 'NAM NGƯ',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/nuoc-mam-nam-ngu-de-nhi-900ml-20230228071002.jpg'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': 'd350cb40-114d-426b-80d3-308eb47df55c',
#     'uomName': 'Chai',
#     'sku': '10008683CHA',
#     'description': 'Nước mắm Nam Ngư Đệ nhị 900ml',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 26500.0,
#     'salePrice': 22000.0,
#     'quantity': 114.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/nuoc-mam-nam-ngu-de-nhi-900ml-20230228071002.jpg',
#     'promotionCode': '2300285902',
#     'promotionType': 'ZB10',
#     'scaleType': 'UPTO',
#     'scaleQuantity': 5.0,
#     'barcode': '8936017361914',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '860a387c-db63-4ec2-b28b-f1cb9bb24231',
#   'itemNo': '10230585',
#   'brand': '10016',
#   'seoName': 'wmnk-tao-gala-balan--s10230585',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2022/tao-gala-ba-lan.png',
#   'description': 'Táo Gala Ba Lan',
#   'name': 'Táo Gala Ba Lan',
#   'itemType': 'ZTRD',
#   'uomId': '69cae86e-32aa-4b9f-a038-d525ac9ec8ab',
#   'uom': 'KG',
#   'uomName': 'Kg',
#   'quantityPerUnit': 1.0,
#   'sku': '10230585KG',
#   'barcode': '2651704000000',
#   'price': 59900.0,
#   'salePrice': 49900.0,
#   'quantity': 492.516,
#   'promotionCode': '2300387386',
#   'promotionType': 'ZB05',
#   'scaleType': 'EQUAL',
#   'scaleQuantity': 1.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '101',
#   'mch2Name': 'Thực phẩm Tươi sống, Chế biến',
#   'mch3': '10106',
#   'mch3Name': 'Trái cây',
#   'mch4': '1010602',
#   'mch4Name': 'Trái cây nhập khẩu',
#   'mch5': '101060209',
#   'mch5Name': 'Táo NK',
#   'brandName': 'TÁO GALA',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2022/tao-gala-ba-lan.png'}],
#   'uoms': [{'uom': 'KG',
#     'uomId': '69cae86e-32aa-4b9f-a038-d525ac9ec8ab',
#     'uomName': 'Kg',
#     'sku': '10230585KG',
#     'description': 'Táo Gala Ba Lan',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 59900.0,
#     'salePrice': 49900.0,
#     'quantity': 492.516,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2022/tao-gala-ba-lan.png',
#     'promotionCode': '2300387386',
#     'promotionType': 'ZB05',
#     'scaleType': 'EQUAL',
#     'scaleQuantity': 1.0,
#     'barcode': '2651704000000',
#     'variants': [{'variantId': '36ef81c1-344d-41cc-bd6f-4c6659057065',
#       'code': '1',
#       'label': '1KG',
#       'quantityPerUnit': 1.0},
#      {'variantId': '8f3e0613-7512-43d8-87cf-d8e5ae47a2f4',
#       'code': '0.5',
#       'label': '0.5KG',
#       'quantityPerUnit': 0.5}]}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '406ea6a1-bce9-4dbd-a3fa-15af2126cd44',
#   'itemNo': '10250375',
#   'brand': '10088',
#   'seoName': 'nam-ngu-nuoc-mam-chai-1.2l--s10250375',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/04/nuoc-mam-nam-ngu-20230419045034.png',
#   'description': 'Nước mắm Nam Ngư  chai 1.2L',
#   'name': 'Nước mắm Nam Ngư  chai 1.2L',
#   'itemType': 'ZTRD',
#   'uomId': '8c652411-256e-4a20-afb0-c37431ff18c6',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10250375CHA',
#   'barcode': '8936136162003',
#   'price': 65000.0,
#   'salePrice': 62000.0,
#   'quantity': 220.0,
#   'promotionCode': '2300285903',
#   'promotionType': 'ZB10',
#   'scaleType': 'UPTO',
#   'scaleQuantity': 5.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020605',
#   'mch4Name': 'Gia vị',
#   'mch5': '102060511',
#   'mch5Name': 'Nước mắm',
#   'brandName': 'NAM NGƯ',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/04/nuoc-mam-nam-ngu-20230419045034.png'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '8c652411-256e-4a20-afb0-c37431ff18c6',
#     'uomName': 'Chai',
#     'sku': '10250375CHA',
#     'description': 'Nước mắm Nam Ngư  chai 1.2L',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 65000.0,
#     'salePrice': 62000.0,
#     'quantity': 220.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/04/nuoc-mam-nam-ngu-20230419045034.png',
#     'promotionCode': '2300285903',
#     'promotionType': 'ZB10',
#     'scaleType': 'UPTO',
#     'scaleQuantity': 5.0,
#     'barcode': '8936136162003',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'ff7376bd-ac2c-4b37-b3b1-21b4320d9552',
#   'itemNo': '10011213',
#   'brand': '10066',
#   'seoName': 'sting-nc-tang-luc-vi-nhan-sam-chai-330ml--s10011213',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/10/thung-sting-vang-chai-20241001084139.png',
#   'description': 'Thùng 24 chai nước tăng lực nhân sâm Sting 330ml',
#   'name': 'Thùng 24 chai nước tăng lực nhân sâm Sting 330ml',
#   'itemType': 'ZTRD',
#   'uomId': 'c6fea4f9-d900-4661-8e82-b34ae51fb44a',
#   'uom': 'T',
#   'uomName': 'Thùng',
#   'quantityPerUnit': 24.0,
#   'sku': '10011213T',
#   'barcode': '58934588173078',
#   'price': 236000.0,
#   'salePrice': 236000.0,
#   'quantity': 1.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10203',
#   'mch3Name': 'Đồ uống, thuốc lá',
#   'mch4': '1020304',
#   'mch4Name': 'Nước uống không cồn và hoa quả',
#   'mch5': '102030407',
#   'mch5Name': 'Nước tăng lực',
#   'brandName': 'STING',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/10/thung-sting-vang-chai-20241001084139.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/1-sting-vang-330-l6-20230914043020.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/infor_sting-chai-vang-20230914043018.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/kv_sting-vang-20230914043020.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2022/162427347554910011213-g6-thung-24-chai-nuoc-tang-luc-sting-huong-dou-toy-do-330ml-og.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/1-sting-vang-330-20230914043042.png'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2022/162427347555010011213-cha-loc-6-chai-nuoc-tang-luc-sting-huong-dou-toy-do-330ml-og.jpg'}],
#   'uoms': [{'uom': 'T',
#     'uomId': 'c6fea4f9-d900-4661-8e82-b34ae51fb44a',
#     'uomName': 'Thùng',
#     'sku': '10011213T',
#     'description': 'Thùng 24 chai nước tăng lực nhân sâm Sting 330ml',
#     'priority': 0,
#     'quantityPerUnit': 24.0,
#     'price': 236000.0,
#     'salePrice': 236000.0,
#     'quantity': 1.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/10/thung-sting-vang-chai-20241001084139.png',
#     'scaleQuantity': 0.0,
#     'barcode': '58934588173078',
#     'variants': []},
#    {'uom': 'G6',
#     'uomId': '1f14db76-4ab3-4c90-9032-3406d6065f89',
#     'uomName': 'Gói 6',
#     'sku': '10011213G6',
#     'description': 'Lốc 6 chai nước tăng lực nhân sâm Sting 330ml',
#     'priority': 0,
#     'quantityPerUnit': 6.0,
#     'price': 60500.0,
#     'salePrice': 60500.0,
#     'quantity': 8.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/1-sting-vang-330-l6-20230914043020.png',
#     'scaleQuantity': 0.0,
#     'barcode': '8934588173035',
#     'variants': []},
#    {'uom': 'CHA',
#     'uomId': 'a9ff066d-c993-454a-bc55-4b7ca87e8cac',
#     'uomName': 'Chai',
#     'sku': '10011213CHA',
#     'description': 'Nước tăng lực nhân sâm Sting chai 330ml',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 10600.0,
#     'salePrice': 10600.0,
#     'quantity': 73.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/09/1-sting-vang-330-20230914043042.png',
#     'scaleQuantity': 0.0,
#     'barcode': '8934588173073',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '27149a02-7e24-40d3-8cb2-8bf02fdc5bff',
#   'itemNo': '10011651',
#   'brand': '10010',
#   'seoName': 'coca-nuoc-ngot-zero-320ml--s10011651',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-3--20241109110412.jpg',
#   'description': 'Thùng 24 lon nước giải khát Zero Coca Cola không đường 330ml',
#   'name': 'Thùng 24 lon nước giải khát Zero Coca Cola không đường 330ml',
#   'itemType': 'ZTRD',
#   'uomId': '6c6275e2-e0b9-4d56-a21e-22eb41af5129',
#   'uom': 'T',
#   'uomName': 'Thùng',
#   'quantityPerUnit': 24.0,
#   'sku': '10011651T',
#   'barcode': '28935049502337',
#   'price': 236000.0,
#   'salePrice': 236000.0,
#   'quantity': 23.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10203',
#   'mch3Name': 'Đồ uống, thuốc lá',
#   'mch4': '1020304',
#   'mch4Name': 'Nước uống không cồn và hoa quả',
#   'mch5': '102030404',
#   'mch5Name': 'Nước ngọt có ga',
#   'brandName': 'COCA-COLA',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-20241109110328.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-2--20241109110347.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-4--20241109110355.jpg'},
#    {'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-3--20241109110412.jpg'}],
#   'uoms': [{'uom': 'T',
#     'uomId': '6c6275e2-e0b9-4d56-a21e-22eb41af5129',
#     'uomName': 'Thùng',
#     'sku': '10011651T',
#     'description': 'Thùng 24 lon nước giải khát Zero Coca Cola không đường 330ml',
#     'priority': 0,
#     'quantityPerUnit': 24.0,
#     'price': 236000.0,
#     'salePrice': 236000.0,
#     'quantity': 23.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-3--20241109110412.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '28935049502337',
#     'variants': []},
#    {'uom': 'G6',
#     'uomId': 'c6eced0b-a655-41fd-b92b-31057e8a2685',
#     'uomName': 'Gói 6',
#     'sku': '10011651G6',
#     'description': 'Lốc 6 lon nước giải khát Zero Coca Cola không đường 330ml',
#     'priority': 0,
#     'quantityPerUnit': 6.0,
#     'price': 61500.0,
#     'salePrice': 61500.0,
#     'quantity': 96.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-2--20241109110347.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8935049590651',
#     'variants': []},
#    {'uom': 'LON',
#     'uomId': 'cc606f36-4ea5-4c30-a1d3-a65854a67277',
#     'uomName': 'Lon',
#     'sku': '10011651LON',
#     'description': 'Nước giải khát Zero Coca Cola không đường lon 330ml',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 10500.0,
#     'salePrice': 10500.0,
#     'quantity': 596.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10011651-20241109110328.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8935049501534',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '260624a1-ce24-4db5-9c37-171000578c4a',
#   'itemNo': '10020777',
#   'brand': '10527',
#   'seoName': 'teddybear-giay-an-rut-mollis-300-to--s10020777',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2022/khan-giay-lua-2-lop-teddy-bear-mollis-goi-300-to_fa53c77d-c0bd-48d2-afaf-c3c269ea3046-og.jpg',
#   'description': 'Khăn giấy lụa 2 lớp Teddy Bear Mollis gói 300 tờ',
#   'name': 'Khăn giấy lụa 2 lớp Teddy Bear Mollis gói 300 tờ',
#   'itemType': 'ZTRD',
#   'uomId': '8488e445-9e60-4df9-9d15-0fb3fb0f5db0',
#   'uom': 'G1',
#   'uomName': 'Gói',
#   'quantityPerUnit': 1.0,
#   'sku': '10020777G1',
#   'barcode': '8938509472399',
#   'price': 29400.0,
#   'salePrice': 29400.0,
#   'quantity': 367.0,
#   'scaleQuantity': 0.0,
#   'mch1': '2',
#   'mch1Name': 'Phi thực phẩm',
#   'mch2': '202',
#   'mch2Name': 'Hoá mỹ phẩm',
#   'mch3': '20201',
#   'mch3Name': 'Giấy và bông',
#   'mch4': '2020102',
#   'mch4Name': 'Giấy ăn, giấy vệ sinh',
#   'mch5': '202010206',
#   'mch5Name': 'Khăn giấy gói',
#   'brandName': 'TEDDYBEAR',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2022/khan-giay-lua-2-lop-teddy-bear-mollis-goi-300-to_fa53c77d-c0bd-48d2-afaf-c3c269ea3046-og.jpg'}],
#   'uoms': [{'uom': 'G1',
#     'uomId': '8488e445-9e60-4df9-9d15-0fb3fb0f5db0',
#     'uomName': 'Gói',
#     'sku': '10020777G1',
#     'description': 'Khăn giấy lụa 2 lớp Teddy Bear Mollis gói 300 tờ',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 29400.0,
#     'salePrice': 29400.0,
#     'quantity': 367.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2022/khan-giay-lua-2-lop-teddy-bear-mollis-goi-300-to_fa53c77d-c0bd-48d2-afaf-c3c269ea3046-og.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8938509472399',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '977be28a-db2a-43c6-b635-cd792f5780cb',
#   'itemNo': '10142177',
#   'brand': '15440',
#   'seoName': 'meizan-hat-nem-thit-xotcr-heo-400gr--s10142177',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10142177-20241108104755.jpg',
#   'description': 'MEIZAN Hạt nêm Thịt, XO,T,CR Heo 400gr',
#   'name': 'MEIZAN Hạt nêm Thịt, XO,T,CR Heo 400gr',
#   'itemType': 'ZTRD',
#   'uomId': '83501960-13c2-48e6-a166-ffc6d9cc9735',
#   'uom': 'G1',
#   'uomName': 'Gói',
#   'quantityPerUnit': 1.0,
#   'sku': '10142177G1',
#   'barcode': '8936134363259',
#   'price': 38000.0,
#   'salePrice': 38000.0,
#   'quantity': 114.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020605',
#   'mch4Name': 'Gia vị',
#   'mch5': '102060501',
#   'mch5Name': 'Bột canh, hạt nêm',
#   'brandName': 'MEIZAN',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10142177-20241108104755.jpg'}],
#   'uoms': [{'uom': 'G1',
#     'uomId': '83501960-13c2-48e6-a166-ffc6d9cc9735',
#     'uomName': 'Gói',
#     'sku': '10142177G1',
#     'description': 'MEIZAN Hạt nêm Thịt, XO,T,CR Heo 400gr',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 38000.0,
#     'salePrice': 38000.0,
#     'quantity': 114.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10142177-20241108104755.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8936134363259',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '11d502a6-d708-4d4b-b335-f123155f0932',
#   'itemNo': '10170268',
#   'brand': '15145',
#   'seoName': 'neptune-hat-nem-4-trong-1-heo-380g--s10170268',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10170268-20241109090540.jpg',
#   'description': 'NEPTUNE Hạt nêm 4 trong 1 - heo 380g',
#   'name': 'NEPTUNE Hạt nêm 4 trong 1 - heo 380g',
#   'itemType': 'ZTRD',
#   'uomId': '85f03497-3665-4036-8bc6-7a338c597b46',
#   'uom': 'G1',
#   'uomName': 'Gói',
#   'quantityPerUnit': 1.0,
#   'sku': '10170268G1',
#   'barcode': '8936134363204',
#   'price': 36100.0,
#   'salePrice': 36100.0,
#   'quantity': 265.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10206',
#   'mch3Name': 'Thực phẩm khô',
#   'mch4': '1020605',
#   'mch4Name': 'Gia vị',
#   'mch5': '102060501',
#   'mch5Name': 'Bột canh, hạt nêm',
#   'brandName': 'NEPTUNE',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10170268-20241109090540.jpg'}],
#   'uoms': [{'uom': 'G1',
#     'uomId': '85f03497-3665-4036-8bc6-7a338c597b46',
#     'uomName': 'Gói',
#     'sku': '10170268G1',
#     'description': 'NEPTUNE Hạt nêm 4 trong 1 - heo 380g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 36100.0,
#     'salePrice': 36100.0,
#     'quantity': 265.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10170268-20241109090540.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8936134363204',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '04c688c4-9b7d-41c9-960d-2fc9c0c19c34',
#   'itemNo': '10171067',
#   'brand': '16009',
#   'seoName': 'chante-nuoc-giat-xa-cao-cap-3.4kg--s10171067',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/chante1.jpg',
#   'description': 'Nước giặt xả cao cấp Chante chai 3.4kg',
#   'name': 'Nước giặt xả cao cấp Chante chai 3.4kg',
#   'itemType': 'ZTRD',
#   'uomId': '4bd6f54d-80b5-443d-848e-10aba7d66308',
#   'uom': 'CHA',
#   'uomName': 'Chai',
#   'quantityPerUnit': 1.0,
#   'sku': '10171067CHA',
#   'barcode': '8936136165004',
#   'price': 225000.0,
#   'salePrice': 225000.0,
#   'quantity': 197.0,
#   'scaleQuantity': 0.0,
#   'mch1': '2',
#   'mch1Name': 'Phi thực phẩm',
#   'mch2': '202',
#   'mch2Name': 'Hoá mỹ phẩm',
#   'mch3': '20202',
#   'mch3Name': 'Hóa phẩm',
#   'mch4': '2020201',
#   'mch4Name': 'Chất giặt tẩy',
#   'mch5': '202020104',
#   'mch5Name': 'Nước giặt',
#   'brandName': 'CHANTE',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/chante1.jpg'}],
#   'uoms': [{'uom': 'CHA',
#     'uomId': '4bd6f54d-80b5-443d-848e-10aba7d66308',
#     'uomName': 'Chai',
#     'sku': '10171067CHA',
#     'description': 'Nước giặt xả cao cấp Chante chai 3.4kg',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 225000.0,
#     'salePrice': 225000.0,
#     'quantity': 197.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/02/chante1.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8936136165004',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': 'f70a91e9-dde9-4379-999a-97066a9090f9',
#   'itemNo': '10171203',
#   'brand': '10121',
#   'seoName': 'elene-gvs-xanh-ngoc-10c-3-lop-loi--s10171203',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/cb65cdf517cc5614abe931328abba3bb-20230510062746.png',
#   'description': 'Giấy vệ sinh Elene  xanh ngọc 10c 3 lớp lõi',
#   'name': 'Giấy vệ sinh Elene  xanh ngọc 10c 3 lớp lõi',
#   'itemType': 'ZTRD',
#   'uomId': '573c6d25-8390-45cf-8b18-f7da48d72a4d',
#   'uom': 'LOC',
#   'uomName': 'Lốc, Lô, Lố',
#   'quantityPerUnit': 1.0,
#   'sku': '10171203LOC',
#   'barcode': '8936020761985',
#   'price': 146300.0,
#   'salePrice': 146300.0,
#   'quantity': 10.0,
#   'scaleQuantity': 0.0,
#   'mch1': '2',
#   'mch1Name': 'Phi thực phẩm',
#   'mch2': '202',
#   'mch2Name': 'Hoá mỹ phẩm',
#   'mch3': '20201',
#   'mch3Name': 'Giấy và bông',
#   'mch4': '2020102',
#   'mch4Name': 'Giấy ăn, giấy vệ sinh',
#   'mch5': '202010205',
#   'mch5Name': 'Giấy vệ sinh',
#   'brandName': 'ELENE',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/cb65cdf517cc5614abe931328abba3bb-20230510062746.png'}],
#   'uoms': [{'uom': 'LOC',
#     'uomId': '573c6d25-8390-45cf-8b18-f7da48d72a4d',
#     'uomName': 'Lốc, Lô, Lố',
#     'sku': '10171203LOC',
#     'description': 'Giấy vệ sinh Elene  xanh ngọc 10c 3 lớp lõi',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 146300.0,
#     'salePrice': 146300.0,
#     'quantity': 10.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2023/05/cb65cdf517cc5614abe931328abba3bb-20230510062746.png',
#     'scaleQuantity': 0.0,
#     'barcode': '8936020761985',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '82321346-0142-46c8-ac39-c2224b81cae8',
#   'itemNo': '10197682',
#   'brand': '10116',
#   'seoName': 'custas-banh-kem-trung-orion-hop-188g--s10197682',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197682-20241117132945.jpg',
#   'description': 'CUSTAS Bánh kem trứng Orion hộp 188g',
#   'name': 'CUSTAS Bánh kem trứng Orion hộp 188g',
#   'itemType': 'ZTRD',
#   'uomId': 'c369f78c-7450-4e19-95a0-ed4ddf661a2e',
#   'uom': 'HOP',
#   'uomName': 'Hộp',
#   'quantityPerUnit': 1.0,
#   'sku': '10197682HOP',
#   'barcode': '8936036029925',
#   'price': 36000.0,
#   'salePrice': 36000.0,
#   'quantity': 35.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10201',
#   'mch3Name': 'Bánh kẹo',
#   'mch4': '1020101',
#   'mch4Name': 'Bánh',
#   'mch5': '102010103',
#   'mch5Name': 'Bánh bông lan',
#   'brandName': 'CUSTAS',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197682-20241117132945.jpg'}],
#   'uoms': [{'uom': 'HOP',
#     'uomId': 'c369f78c-7450-4e19-95a0-ed4ddf661a2e',
#     'uomName': 'Hộp',
#     'sku': '10197682HOP',
#     'description': 'CUSTAS Bánh kem trứng Orion hộp 188g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 36000.0,
#     'salePrice': 36000.0,
#     'quantity': 35.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197682-20241117132945.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8936036029925',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '4be99ee9-fc12-42ec-85c0-87ea53657f7c',
#   'itemNo': '10197683',
#   'brand': '10056',
#   'seoName': 'chocopie-banh-orion-hop-264g290.4g--s10197683',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197683-20241119115353.jpg',
#   'description': 'CHOCOPIE Bánh Orion hộp 264g/290.4g',
#   'name': 'CHOCOPIE Bánh Orion hộp 264g/290.4g',
#   'itemType': 'ZTRD',
#   'uomId': '6efc8d57-8778-402f-a851-45e87cd51a54',
#   'uom': 'HOP',
#   'uomName': 'Hộp',
#   'quantityPerUnit': 1.0,
#   'sku': '10197683HOP',
#   'barcode': '8936036029048',
#   'price': 36000.0,
#   'salePrice': 36000.0,
#   'quantity': 87.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10201',
#   'mch3Name': 'Bánh kẹo',
#   'mch4': '1020101',
#   'mch4Name': 'Bánh',
#   'mch5': '102010109',
#   'mch5Name': 'Bánh pie',
#   'brandName': 'CHOCOPIE',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197683-20241119115353.jpg'}],
#   'uoms': [{'uom': 'HOP',
#     'uomId': '6efc8d57-8778-402f-a851-45e87cd51a54',
#     'uomName': 'Hộp',
#     'sku': '10197683HOP',
#     'description': 'CHOCOPIE Bánh Orion hộp 264g/290.4g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 36000.0,
#     'salePrice': 36000.0,
#     'quantity': 87.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10197683-20241119115353.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8936036029048',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '4ac2ebe5-9749-480d-bd41-cea4c0fb01df',
#   'itemNo': '10252767',
#   'brand': '10103',
#   'seoName': 'jinju-banh-gao-muoi-hong-134.4g--s10252767',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10252767-20241109110716.jpg',
#   'description': 'JINJU Bánh gạo muối hồng 134.4g',
#   'name': 'JINJU Bánh gạo muối hồng 134.4g',
#   'itemType': 'ZTRD',
#   'uomId': '7555cd04-7d87-4e73-b835-4c06d171754b',
#   'uom': 'G1',
#   'uomName': 'Gói',
#   'quantityPerUnit': 1.0,
#   'sku': '10252767G1',
#   'barcode': '8938532962584',
#   'price': 26000.0,
#   'salePrice': 26000.0,
#   'quantity': 183.0,
#   'scaleQuantity': 0.0,
#   'mch1': '1',
#   'mch1Name': 'Thực phẩm',
#   'mch2': '102',
#   'mch2Name': 'Thực phẩm công nghệ',
#   'mch3': '10201',
#   'mch3Name': 'Bánh kẹo',
#   'mch4': '1020101',
#   'mch4Name': 'Bánh',
#   'mch5': '102010104',
#   'mch5Name': 'Bánh gạo',
#   'brandName': 'RICHY',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10252767-20241109110716.jpg'}],
#   'uoms': [{'uom': 'G1',
#     'uomId': '7555cd04-7d87-4e73-b835-4c06d171754b',
#     'uomName': 'Gói',
#     'sku': '10252767G1',
#     'description': 'JINJU Bánh gạo muối hồng 134.4g',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 26000.0,
#     'salePrice': 26000.0,
#     'quantity': 183.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/11/10252767-20241109110716.jpg',
#     'scaleQuantity': 0.0,
#     'barcode': '8938532962584',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'},
#  {'id': '8901a4a0-5ae1-4c7b-a40d-a8d0ff91007b',
#   'itemNo': '10334816',
#   'brand': '10098',
#   'seoName': 'lix-nrc-sieu-sach-tra-xanh-3.5kg3.6kg--s10334816',
#   'isAlcohol': False,
#   'mediaUrl': 'https://hcm.fstorage.vn/images/2024/07/screenshot_1-20240726061805.png',
#   'description': 'LIX NRC Siêu sạch trà xanh 3.5kg/3.6kg',
#   'name': 'LIX NRC Siêu sạch trà xanh 3.5kg/3.6kg',
#   'itemType': 'ZTRD',
#   'uomId': '7c4e244a-b324-4893-a13d-bb784b8f5495',
#   'uom': 'CAN',
#   'uomName': 'Can',
#   'quantityPerUnit': 1.0,
#   'sku': '10334816CAN',
#   'barcode': '8934669493540',
#   'price': 112000.0,
#   'salePrice': 112000.0,
#   'quantity': 275.0,
#   'scaleQuantity': 0.0,
#   'mch1': '2',
#   'mch1Name': 'Phi thực phẩm',
#   'mch2': '202',
#   'mch2Name': 'Hoá mỹ phẩm',
#   'mch3': '20202',
#   'mch3Name': 'Hóa phẩm',
#   'mch4': '2020202',
#   'mch4Name': 'Vệ sinh nhà',
#   'mch5': '202020205',
#   'mch5Name': 'Nước rửa chén bát',
#   'brandName': 'LIX',
#   'categoryCode': 'MENU114',
#   'categoryName': 'Giá Siêu Rẻ',
#   'mediaItems': [{'mediaUrl': 'https://hcm.fstorage.vn/images/2024/07/screenshot_1-20240726061805.png'}],
#   'uoms': [{'uom': 'CAN',
#     'uomId': '7c4e244a-b324-4893-a13d-bb784b8f5495',
#     'uomName': 'Can',
#     'sku': '10334816CAN',
#     'description': 'LIX NRC Siêu sạch trà xanh 3.5kg/3.6kg',
#     'priority': 0,
#     'quantityPerUnit': 1.0,
#     'price': 112000.0,
#     'salePrice': 112000.0,
#     'quantity': 275.0,
#     'mediaUrl': 'https://hcm.fstorage.vn/images/2024/07/screenshot_1-20240726061805.png',
#     'scaleQuantity': 0.0,
#     'barcode': '8934669493540',
#     'variants': []}],
#   'frameUrl': 'https://hcm.fstorage.vn/images/2024/09/1artboard-7-copy-7-20240906032855.png'}]

# %%
def clean_product_data(category, raw_products):

    cleaned_products = []

    # go through the raw data and select only the necessary fields
    for product in raw_products:
        cleaned_products.append({
            "category_code": category["code"],
            "name": product["name"],
            "price": product["price"],
            "uom": product["uom"],
            "supermarket": 'Winmart'
        })

    return cleaned_products

# %%
fetched_categories_count = 0    # counter for fetching progress tracker

# Create the file first with headers
products_df = pd.DataFrame(columns=["category_code", "name", "price", "uom", "supermarket"])
products_df.to_csv(f'products-{CHECK_DATE}-winmart.csv', index=False, mode='w')

for category in categories_end:
    raw_products = fetch_products(category) # fetch products
    new_products = clean_product_data(category, raw_products) # select only relevant data and add new products to the list

    products_df = pd.DataFrame(new_products)
    products_df.to_csv(f'products-{CHECK_DATE}-winmart.csv', index=False, mode='a', header=False)

    fetched_categories_count += 1
    print(f'№ {category["code"]} finished, {fetched_categories_count} out of {total_categories_count} categories fetched')
    time.sleep(random.uniform(1, 5))

print(f'Fetching complete, see the result in products-{CHECK_DATE}-winmart.csv')
# Out:
# 8..16..24..32..40..48..56..64..72..80..88..94..№ MENU01133 finished, 1 out of 5 categories fetched
# 4..№ MENU01136 finished, 2 out of 5 categories fetched
# 8..16..24..32..40..45..№ MENU01170 finished, 3 out of 5 categories fetched
# 3..№ MENU26 finished, 4 out of 5 categories fetched
# 8..16..24..32..40..48..56..60..№ MENU27 finished, 5 out of 5 categories fetched
# Fetching complete, see the result in products-2025-03-06-winmart.csv

# %% [markdown]
# ---
#
# Below is filtering and price normalization
#
# ---

# %%
import pandas as pd
import re

# %%
categories = pd.read_csv('categories-2025-03-06-winmart.csv')
products_original = pd.read_csv('products-2025-03-06-winmart-complete.csv')
products = products_original.drop(['category_code'], axis=1)    # drop category_code column as it's actually unnecessary

# %%
categories
# Out:
#          code                          name parent_id       parent_name  \
# 0     MENU114                   Giá Siêu Rẻ       NaN               NaN
# 1      MENU51               Ưu Đãi Hội Viên       NaN               NaN
# 2      MENU08                  Sữa các loại       NaN               NaN
# 3    MENU0133                      Sữa Tươi    MENU08      Sữa các loại
# 4    MENU0134             Sữa Hạt - Sữa Đậu    MENU08      Sữa các loại
# ..        ...                           ...       ...               ...
# 87  MENU01133               Đồ dùng nhà bếp    MENU25  Đồ Dùng Gia Đình
# 88  MENU01136  Thiết bị dùng điện trong nhà    MENU25  Đồ Dùng Gia Đình
# 89  MENU01170               Vệ Sinh Nhà Cửa    MENU25  Đồ Dùng Gia Đình
# 90     MENU26                 Điện Gia Dụng       NaN               NaN
# 91     MENU27      Văn Phòng Phẩm - Đồ Chơi       NaN               NaN
#
#     has_child                                  slug  level
# 0       False                     gia-sieu-re--c114      1
# 1       False                  uu-dai-hoi-vien--c51      1
# 2        True                     sua-cac-loai--c08      1
# 3       False                       sua-tuoi--c0133      2
# 4       False                sua-hat-sua-dau--c0134      2
# ..        ...                                   ...    ...
# 87      False               do-dung-nha-bep--c01133      2
# 88      False  thiet-bi-dung-dien-trong-nha--c01136      2
# 89      False               ve-sinh-nha-cua--c01170      2
# 90      False                    dien-gia-dung--c26      1
# 91      False           van-phong-pham-do-choi--c27      1
#
# [92 rows x 7 columns]

# %%
products
# Out:
#                                                    name     price  uom  \
# 0               LIX Nước giặt hương nắng hạ 3,3kg/3,1kg  199000.0  CAN
# 1                             GREEN ACE Dầu đậu nành 2L  129000.0  CHA
# 2     Nước uống sữa trái cây bổ dưỡng hương cam Nutr...   29000.0  CHA
# 3     Nước uống sữa trái cây hương dâu Nutri Boost c...   29000.0  CHA
# 4                           Dầu đậu nành Meizan chai 2L  128900.0  CHA
# ...                                                 ...       ...  ...
# 3507                              Túi bút Deli 19x5x5cm   43000.0  CAI
# 3508                              Túi bút Deli 19x5x5cm   43500.0  CAI
# 3509                      Keo siêu dính Scotch AD113 2G   31000.0  CAI
# 3510    Bao lì xì (8.5x17cm) -Hiện đại- Giao ngẫu nhiên   15300.0  XAP
# 3511         Nhãn vở Thiên Long TP-NBL03 (8 cái) xấp 5    13100.0  XAP
#
#      supermarket
# 0        Winmart
# 1        Winmart
# 2        Winmart
# 3        Winmart
# 4        Winmart
# ...          ...
# 3507     Winmart
# 3508     Winmart
# 3509     Winmart
# 3510     Winmart
# 3511     Winmart
#
# [3512 rows x 4 columns]

# %%
products = products.drop_duplicates() # remove duplicates
products['name'] = products['name'].str.strip() # remove extra spaces
products
# Out:
#                                                    name     price  uom  \
# 0               LIX Nước giặt hương nắng hạ 3,3kg/3,1kg  199000.0  CAN
# 1                             GREEN ACE Dầu đậu nành 2L  129000.0  CHA
# 2     Nước uống sữa trái cây bổ dưỡng hương cam Nutr...   29000.0  CHA
# 3     Nước uống sữa trái cây hương dâu Nutri Boost c...   29000.0  CHA
# 4                           Dầu đậu nành Meizan chai 2L  128900.0  CHA
# ...                                                 ...       ...  ...
# 3507                              Túi bút Deli 19x5x5cm   43000.0  CAI
# 3508                              Túi bút Deli 19x5x5cm   43500.0  CAI
# 3509                      Keo siêu dính Scotch AD113 2G   31000.0  CAI
# 3510    Bao lì xì (8.5x17cm) -Hiện đại- Giao ngẫu nhiên   15300.0  XAP
# 3511          Nhãn vở Thiên Long TP-NBL03 (8 cái) xấp 5   13100.0  XAP
#
#      supermarket
# 0        Winmart
# 1        Winmart
# 2        Winmart
# 3        Winmart
# 4        Winmart
# ...          ...
# 3507     Winmart
# 3508     Winmart
# 3509     Winmart
# 3510     Winmart
# 3511     Winmart
#
# [3436 rows x 4 columns]

# %%
product_regex_map = {
    # 'rice': r'^gạo(?!.*lứt)',
    # 'bread': r'^bánh (mì|mỳ|sandwich)(?!.*(bơ|hoa|chà|thịt))',
    # 'chicken_fillet': r'(fillet|phi lê|\bức)(?!.*đùi).*gà',
    # 'pork_leg': r'đùi.*heo',
    # 'egg': r'^trứng gà',
    # 'cucumber': r'^dưa.*(chuột|leo)(?!.*ngâm)',
    # 'carrot': r'^cà rốt',
    # 'onion': r'^hành tây',
    # 'tomato': r'^cà chua',
    # 'cabbage': r'bắp cải trắng',
    # 'eggplant': r'cà tím',
    # 'banana': r'^chuối(?!.*sấy)',
    # 'orange': r'^cam',
    # 'milk': r'^(thùng.*sữa|sữa|lốc.*sữa)(?!.*(vị|hương|có đường|ít đường|socola|sô cô la|dâu|chua|lên men|bắp|lact|yến)).*(trùng|tươi|tự nhiên)',
    # 'yogurt': r'^(sữa chua|lốc.*hộp.*sữa chua)(?!.*(uống|lên men|fristi|chai))',
    # 'condensed_milk': r'sữa đặc',
    # 'black_tea': r'^trà\b(?!.*(ml|l\b|lít|sữa|gừng|nestea|atiso|ice|xanh|ô long|nhài|tôm|thái|hòa tan|zoga))',
    # 'green_tea': r'^trà\b(?!.*(ml|l\b|lít|sữa|gừng|nestea|atiso|ice|đen|hòa tan|zoga|hoa cúc|ceylon|đào))',
    # 'ground_coffee': r'^(cà phê|café)(?!.*hòa tan).*(bột|xay|sáng|chế phin|nâu|khát)',
    # 'sugar': r'^đường.*(pure|trắng|mía)',
    # 'salt': r'^muối.*biển',
    # 'sunflower_oil': r'dầu.*hướng dương',
    # 'soybean_oil': r'dầu.*nành',
    # 'water': r'^nước (uống|khoáng|tinh)(?!.*(vị|sữa|tăng|ion))',
    # 'spaghetti': r'^mì(?!.*(kool|xốt)).*(ý|spag)',
    # 'rice_noodles': r'^bún.*safoco',
    # 'tofu': r'^(đậu|tàu) hũ(?!.*(chiên|trứng))',
    # 'water_spinach': r'^rau.*muống',
    # 'mango': r'^xoài(?!.*sấy)',
    # 'fish_sauce': r'^nước mắm(?!.*ớt)'
}
product_regex_list = '|'.join(product_regex_map.values())
product_regex_list
# Out:
# '^gạo(?!.*lứt)'

# %%
filtered_products = products.loc[products.name.str.contains(product_regex_list, case=False, regex=True)]
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None):
    display(filtered_products)
# Out:
#                                      name     price uom supermarket
# 6        Gạo Ngọc Nương ST 25 đặc sản 3Kg  123000.0  G1     Winmart
# 65    Gạo ST25 Giống Cây Trồng TW túi 3kg  107000.0  G1     Winmart
# 2490        Gạo Ngọc Nương Lức đỏ túi 1kg   51000.0  G1     Winmart
# 2491         Gạo ST25  Ngọc Nương túi 5Kg  189000.0  G1     Winmart
# 2492  Gạo Lúa Tôm ST25 Ngọc Nương túi 5Kg  199000.0  G1     Winmart
# 2494        Gạo Japonica Neptune bịch 5kg  137600.0  G1     Winmart
# 2497             Gạo Ngọc Nương ST25 3 Kg  115000.0  G1     Winmart

# %%
def assign_product_type(row):
    name = row['name']
    for product_type, regex in product_regex_map.items():
        match = re.search(regex, name, flags=re.IGNORECASE)
        if match:
            return product_type
    return None

filtered_products = filtered_products.copy()  # recreate the dataframe
filtered_products.loc[:,'product_type'] = filtered_products.apply(assign_product_type, axis=1)
filtered_products
# Out:
#                                     name     price  uom supermarket  \
# 1              GREEN ACE Dầu đậu nành 2L  129000.0  CHA     Winmart
# 4            Dầu đậu nành Meizan chai 2L  128900.0  CHA     Winmart
# 6       Gạo Ngọc Nương ST 25 đặc sản 3Kg  123000.0   G1     Winmart
# 9            Dầu đậu nành Meizan chai 1L   55800.0  CHA     Winmart
# 10         Nước mắm Nam Ngư Đệ nhị 900ml   26500.0  CHA     Winmart
# ...                                  ...       ...  ...         ...
# 3213  Trứng Gà Sạch O'LALA hộp 10_Size L   30500.0  HOP     Winmart
# 3216      Trứng Gà Ta O'LALA Sạch giỏ 10   43000.0  HOP     Winmart
# 3217       Tàu hũ bổ dưỡng Tafu gói 300g   10400.0  CAI     Winmart
# 3221         Tàu hũ mềm Ichiban hộp 300g   12800.0  HOP     Winmart
# 3222     Đậu hũ đậu hũ Làng Mơ Thai corp   15900.0  HOP     Winmart
#
#      product_type
# 1     soybean_oil
# 4     soybean_oil
# 6            rice
# 9     soybean_oil
# 10     fish_sauce
# ...           ...
# 3213          egg
# 3216          egg
# 3217         tofu
# 3221         tofu
# 3222         tofu
#
# [215 rows x 5 columns]

# %%
def extract_weight(row):
    name, uom = row['name'], row['uom']
    
    # some products are sold in groups, so we'll check that first
    match = re.search(r'G(\d)', uom)
    if match:
        number = int(match.group(1))
    elif uom == 'T':
        match = re.search(r'(\d+)\s?(gói|hộp|túi)', name, flags=re.IGNORECASE)
        if match:
            number = int(match.group(1))
    else:
        number = 1
    
    match = re.search(r'(\d+|\d+[,.]\d+)\s?(g\b|kg)', name, flags=re.IGNORECASE)
    if match:
        weight = float(match.group(1).replace(',', '.'))
        unit = match.group(2)
        return number * weight * 1000 if unit in ['kg','Kg'] else number * weight
    # if name doesn't contain anything, check uom
    if uom == 'KG':
        weight = 1000
        return weight
    
    return None  # if nothing matched

def extract_number_of_units(row):
    name, product_type, uom = row['name'], row['product_type'], row['uom']
    
    # first, check name
    match = re.search(r'(\d+)\s?(quả|trái)', name, flags=re.IGNORECASE)
    if match:
        number_of_units = int(match.group(1))
        return number_of_units
    # for eggs let's take any number from the name (because this is how they specify it)
    match = re.search(r'(\d+)', name)
    if match and product_type == 'egg':
        number_of_units = int(match.group(1))
        return number_of_units
    
    return None  # if nothing matched

def extract_volume(row):
    name, uom = row['name'], row['uom']
    
    # drinks are often sold in groups, so we'll check that first
    match = re.search(r'G(\d)', uom)
    if match:
        number = int(match.group(1))
    elif uom == 'T':
        match = re.search(r'(\d+)\s?(gói|hộp|túi|chai)', name, flags=re.IGNORECASE)
        if match:
            number = int(match.group(1))
        else:
            number = 0
    else:
        number = 1
    
    match = re.search(r'(\d+|\d+[,.]\d+)\s?(ml|l\b|lít)', name, flags=re.IGNORECASE)
    if match:
        volume = float(match.group(1).replace(',', '.'))
        unit = match.group(2)
        return number * volume * 1000 if unit in ['l', 'L', 'lít'] else number * volume

    return None  # if nothing matched

filtered_products = filtered_products.copy()  # recreate the dataframe
# extract and calculate weights
filtered_products.loc[:,'weight'] = filtered_products.apply(extract_weight, axis=1)  # a column with weigths in grams
filtered_products.loc[:,'price_kg'] = filtered_products.price / filtered_products.weight * 1000   # a column with prices per kg
# # extract and calculate number of units (for products with units)
filtered_products.loc[:,'number_of_units'] = filtered_products.apply(extract_number_of_units, axis=1)  # a column with number of units
filtered_products.loc[:,'price_unit'] = filtered_products.price / filtered_products.number_of_units   # a column with prices per unit
# extract and calculate volume
filtered_products.loc[:,'volume'] = filtered_products.apply(extract_volume, axis=1)  # a column with volume in ml
filtered_products.loc[:,'price_lit'] = filtered_products.price / filtered_products.volume * 1000   # a column with prices per liter
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None, 'display.float_format', '{:.1f}'.format):
    display(filtered_products)
# Out:
#                                                                         name  \
# 1                                                  GREEN ACE Dầu đậu nành 2L
# 4                                                Dầu đậu nành Meizan chai 2L
# 6                                           Gạo Ngọc Nương ST 25 đặc sản 3Kg
# 9                                                Dầu đậu nành Meizan chai 1L
# 10                                             Nước mắm Nam Ngư Đệ nhị 900ml
# 11                                               Nước mắm Nam Ngư  chai 1.2L
# 28                                                Rau muống WinEco gói  500g
# 41                                                        Cà chua đỏ  WinEco
# 44                                                 MEATDELI Thịt đùi heo (S)
# 48                                             MEATDELI Thịt Nạc đùi heo (S)
# 56                                            Dưa chuột baby WinEco gói 500g
# 65                                       Gạo ST25 Giống Cây Trồng TW túi 3kg
# 68                                                                Cam Ai Cập
# 77               Thùng 48 hộp sữa tươi tiệt trùng Vinamilk không đường 180ml
# 78                         Sữa tiệt trùng Cô gái Hà Lan không đường hộp 1lít
# 2504              NaN         NaN     NaN        NaN
# 2676              NaN         NaN     NaN        NaN
# 2681              NaN         NaN     NaN        NaN
# 2684              NaN         NaN     NaN        NaN
# 2698              NaN         NaN     NaN        NaN
# 2788              NaN         NaN     NaN        NaN
# 2826              NaN         NaN  1000.0    69100.0
# 2827              NaN         NaN  2000.0    69050.0
# 2828              NaN         NaN  5000.0    67860.0
# 2833              NaN         NaN  1000.0    84900.0
# 2835              NaN         NaN  5000.0    63260.0
# 2838              NaN         NaN  5000.0    68840.0
# 2839              NaN         NaN  2000.0    70200.0
# 2841              NaN         NaN  1000.0    70200.0
# 2848              NaN         NaN  1000.0    68000.0
# 2853              NaN         NaN  2000.0    70300.0
# 2854              NaN         NaN  1000.0    68500.0
# 2856              NaN         NaN  2000.0    68750.0
# 2861              NaN         NaN  1000.0    68200.0
# 2867              NaN         NaN  1000.0    70300.0
# 2873              NaN         NaN  1800.0    77777.8
# 2874              NaN         NaN  1000.0    82900.0
# 2875              NaN         NaN  1000.0    69300.0
# 2878              NaN         NaN   750.0    79200.0
# 2879              NaN         NaN   500.0   229800.0
# 2880              NaN         NaN   650.0   151230.8
# 2882              NaN         NaN   520.0   262115.4
# 2883              NaN         NaN   750.0    69333.3
# 2884              NaN         NaN   520.0   243269.2
# 2885              NaN         NaN   900.0    66888.9
# 2886              NaN         NaN   520.0   196346.2
# 2889              NaN         NaN   525.0   252761.9
# 2890              NaN         NaN   525.0   226285.7
# 2891              NaN         NaN   525.0   205904.8
# 2892              NaN         NaN   500.0   166800.0
# 2893              NaN         NaN   500.0   165200.0
# 2894              NaN         NaN    50.0  3982000.0
# 2895              NaN         NaN   500.0   208200.0
# 2896              NaN         NaN   250.0   292400.0
# 2897              NaN         NaN     NaN        NaN
# 2898              NaN         NaN   500.0   276000.0
# 2899              NaN         NaN   500.0   110000.0
# 2900              NaN         NaN    50.0   360000.0
# 2901              NaN         NaN    50.0   508000.0
# 2902              NaN         NaN   620.0    96612.9
# 2903              NaN         NaN   750.0   115200.0
# 2904              NaN         NaN   720.0    84722.2
# 2905              NaN         NaN     NaN        NaN
# 2907              NaN         NaN   500.0   130000.0
# 2911              NaN         NaN   620.0   105645.2
# 2912              NaN         NaN   490.0   140612.2
# 2913              NaN         NaN   490.0   295918.4
# 2914              NaN         NaN   610.0   135245.9
# 2915              NaN         NaN   490.0    55510.2
# 2916              NaN         NaN   520.0   198461.5
# 2917              NaN         NaN     NaN        NaN
# 2919              NaN         NaN     NaN        NaN
# 2923              NaN         NaN     NaN        NaN
# 2926              NaN         NaN     NaN        NaN
# 2990              NaN         NaN     NaN        NaN
# 3210             10.0      3380.0     NaN        NaN
# 3211              6.0      3416.7     NaN        NaN
# 3213             10.0      3050.0     NaN        NaN
# 3216             10.0      4300.0     NaN        NaN
# 3217              NaN         NaN     NaN        NaN
# 3221              NaN         NaN     NaN        NaN
# 3222              NaN         NaN     NaN        NaN

# %%
filtered_products.to_csv(f'filtered_products-2025-03-06-winmart.csv')
